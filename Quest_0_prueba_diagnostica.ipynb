# %% [markdown]
# #Puerba diganostica

# %% [markdown]
# #prueba diagnostica
#
# 1.
#
#
# ```
# Algoritmo trabajo
# 	n=i
# repetir
# 	escribir("eliga un numero")
# 	leer n
# 	Escribir ("el numero es negativo")
# hasta que 0<n
#
# escribir("el numero se concidera como positivo")
# FinAlgoritmo
# ```
#
#
# ```
# #Algoritmo trabajo
# num1=n
#
# 	Repetir
# 		Escribir ("escriba tu edad")
# 		leer num1
# 		Escribir ("menor de edad ")
# 		leer num1
# 	Hasta Que num1>18
# 	Escribir ("mayor de edad")
#
#
#
# FinAlgoritmo
# ```
#
#
# ```
# # Algoritmo trabajo
# 	Escribir ("escriba un numero")
# 	leer num1
# 	Escribir ("escriba otro numero")
# 	leer num2
# 	Si num1>num2 Entonces
# 		Escribir ("el "),num1,(" es mayor que "),num2
# 	SiNo
# 		Escribir (" el "),num2,(" es mayor que "),num1
# 	Fin Si
# FinAlgoritmo
# ```
#
#
# ```
# #Algoritmo trabajo
# 	Escribir ("escriba la nota final")
# 	leer num2
# 	Si 60>=num2 Entonces
# 		Escribir ("reprobo la materia")
# 	SiNo
# 		Escribir (" aprobo la materia")
# 	Fin Si
# FinAlgoritmo
#
# ```
# definir el numero como entero
# agregar un codigo que diga que si el numero es dividido en 2 se concidere como
# un numero pa, si no se puede divir con dicho numero se concidera impar
#
# ```
# # Algoritmo trabajo
#
# 	Escribir ("escriba un numero")
# 	leer num1
#
# 	Escribir ("escriba otro numero")
# 	leer num2
#
# 	 Escribir ("escriba otro numero")
# 	 leer num3
#
# 	Si num1>num2 o num1> num3 Entonces
# 		Escribir ("el "),num1,(" es mayor que "),num2, (" y "), num3
# 		si no num2>num1 o num2>num3 Entonces
# 			Escribir ("el "),num2,(" es mayor que "),num1, (" y "), num3
# 		si num3>num1 o num3>num2 Entonces
# 		fin si
# 	Fin Si
# 	fin si
# FinAlgoritmo
# ```
# definir los dias del mes y elejir dos dias que sea bisisestos, agreagar "escribri dia del mes" y dependiendo del diga que elijas sera bisisesto o no
#
# ```
